# %%
import requests
import time
from random import random
from bs4 import BeautifulSoup

data = []


#need to put page as '1' or target page is null

page = 200
final_page = "page=1"
while True:
    #generates delay:
    delay = 0.5

    current = "https://tiki.vn/laptop-may-vi-tinh/c1846?src=c.1846.hamburger_menu_fly_out_banner&page=" + str(page)
    print("Current: ", current)

    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}
    r = requests.get(current, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")
    
    print("Current page:", page)

    # print("Generating soup works:", soup.prettify()[:100])

    products = soup.find_all("a", {"class": "product-item"})

    print("Generating product list works:", len(products))
    
    
    if len(products) != 0:
        
        for product in products:
            d = {'product_id':'', 'free_shipping':'', 'title':'', 'price':'', 'image_url':'', 'reviewer_tot': ''}

            try:
                d['product_id'] = (product['href'].split('-')[-1])[:-5] 
            except:
                d['product_id'] = 0
                print("product_id empty")
            try:
                d['title'] = product.find('div', {'class':'name'}).text
            except:
                d['title'] = 0
                print("title empty")
            try:
                d['price'] = product.find('div', {'class':'price-discount__price'}).text
            except:
                d['price'] = 0
                print("price empty")
            try:
                d['image_url'] = product.img['src']
            except:
                d['image_url'] = 0
                print("image_url empty")
            try:
                d['free_shipping'] = bool(product.find('div', {'class':'badge-top'}))
            except:
                d['free_shipping'] = 0
                print("free shipping empty")
            try:
                d['reviewer_tot'] = product.find('div', {'class':'review'}).text
            except:
                d['reviewer_tot'] = 0
                print("review_tot empty")

            data.append(d)
    else:

        break


    page += 1
    print(f"Page at the end of loop {page}")

    #if target_page == final_page and page != 1:
        #print("Exception")
        #break
    time.sleep(delay)

# %%
import pandas as pd
table = pd.DataFrame(data)
table.head(5)
# Out:
#   product_id  free_shipping  \
# 0   p3054369           True
# 1    p405243           True
# 2    p547563           True
# 3    p405240           True
# 4    p356188           True
#
#                                                title      price  \
# 0  Phần Mềm Diệt Virus BKAV Profressional 1 PC 12...  195.000 ₫
# 1  USB Kingston DT100G3 32GB USB 3.0 - Hàng Chính...   87.000 ₫
# 2  Bộ Kích Sóng Wifi Repeater 300Mbps Totolink EX...  195.000 ₫
# 3  USB Kingston DT100G3 16GB USB 3.0 - Hàng Chính...  115.000 ₫
# 4       Chuột Có Dây Logitech B100 - Hàng Chính Hãng   59.000 ₫
#
#                                            image_url reviewer_tot
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...        (890)
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...       (1540)
# 2  https://salt.tikicdn.com/cache/280x280/ts/prod...       (1489)
# 3  https://salt.tikicdn.com/cache/280x280/media/c...       (1474)
# 4  https://salt.tikicdn.com/cache/280x280/ts/prod...       (1211)
